# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./nyu.h5
# Out:
# --2023-07-03 20:40:59--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.218.63.11, 52.218.97.210, 52.218.24.18, ...
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.218.63.11|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./nyu.h5’
#
# ./nyu.h5            100%[===================>] 164.89M  6.19MB/s    in 25s
#
# 2023-07-03 20:41:24 (6.62 MB/s) - ‘./nyu.h5’ saved [172897376/172897376]

# %%
# !python test.py --model model.h5
# Out:
# Loading model...
#
# Model loaded (model.h5).
#
# Loaded (12) images of size (480, 640, 3).
# 6/6 [==============================] - 8s 948ms/step
# /home/mohamed/miniconda3/envs/py3-10/lib/python3.10/site-packages/skimage/_shared/utils.py:338: FutureWarning: `multichannel` is a deprecated argument name for `montage`. It will be removed in version 1.0.Please use `channel_axis` instead.
#   return func(*args, **kwargs)
# Figure(1000x500)

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./test.png') )

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./test.png') )
